# %% [markdown]
# <a href="https://colab.research.google.com/github/Hairul008/Hairul_Praktikum-Machine-Learning/blob/main/ML(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# . Pre-processing citra pada machine learning

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/Barca.png', 0)

# %%
resized_img = cv2.resize(img, (300, 400))

# %%
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=L size=300x400>

# %%
img_median = cv2.medianBlur(resized_img, 7)

# %%
cv2_imshow(img_median)
# Out:
# <PIL.Image.Image image mode=L size=300x400>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img = cv2.imread('/content/Barca.png')

# %%
resized_img = cv2.resize(img, (300, 400))

# %%
hsv_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2HSV)

# %%
hsv_img[:,:,2] += 50

# %%
cv2_imshow(hsv_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %%
brightened_img = cv2.cvtColor(hsv_img, cv2.COLOR_HSV2BGR)

# %%
cv2_imshow(brightened_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %% [markdown]
# Pre-processing text pada machine learning

# %%
# !pip install Sastrawi

# %%
import string
import nltk
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = "Perkenalkan nama saya Hairul, saya adalah mahasiswa disalah satu universitas di kota palu. Namanya adalah Universitas Tadulako. saya angkatan 2022, hobi saya futsal dan memancing"

# %%
text = text.lower()

# %%
tokens = word_tokenize(text)

tokens = [token for token in tokens if token not in string.punctuation]

tokens = [token for token in tokens if not token.isnumeric()]

tokens
# Out:
# ['perkenalkan',
#  'nama',
#  'saya',
#  'hairul',
#  'saya',
#  'adalah',
#  'mahasiswa',
#  'disalah',
#  'satu',
#  'universitas',
#  'di',
#  'kota',
#  'palu',
#  'namanya',
#  'adalah',
#  'universitas',
#  'tadulako',
#  'saya',
#  'angkatan',
#  'hobi',
#  'saya',
#  'futsal',
#  'dan',
#  'memancing']

# %%
stopwords = nltk.corpus.stopwords.words('indonesian')

tokens = [token for token in tokens if token not in stopwords]

stopwords
# Out:
# ['perkenalkan',
#  'nama',
#  'hairul',
#  'mahasiswa',
#  'disalah',
#  'universitas',
#  'kota',
#  'palu',
#  'namanya',
#  'universitas',
#  'tadulako',
#  'angkatan',
#  'hobi',
#  'futsal',
#  'memancing']

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

stemmed_tokens = [stemmer.stem(token) for token in tokens]

stemmed_tokens
# Out:
# ['kenal',
#  'nama',
#  'hairul',
#  'mahasiswa',
#  'salah',
#  'universitas',
#  'kota',
#  'palu',
#  'nama',
#  'universitas',
#  'tadulako',
#  'angkat',
#  'hobi',
#  'futsal',
#  'pancing']

# %%
processed_text = ' '.join(stemmed_tokens)

print(processed_text)
# Out:
# kenal nama hairul mahasiswa salah universitas kota palu nama universitas tadulako angkat hobi futsal pancing

# %% [markdown]
# Pre-processing time series pada machine learning

# %% [markdown]
# Menghapus duplikat

# %%
import pandas as pd
import numpy as np

# %%
data_RDD = {'date':['2024-01-01', '2024-01-02', '2024-01-02', '2024-01-03', '2024-01-03'], 'value':[1,2,3,4,5]}
df_RDD = pd.DataFrame(data_RDD)

df_RDD
# Out:
#          date  value
# 0  2024-01-01      1
# 1  2024-01-02      2
# 2  2024-01-02      3
# 3  2024-01-03      4
# 4  2024-01-03      5

# %%
df_RDD['date'] = pd.to_datetime(df_RDD['date'])

# %%
RDD = df_RDD.drop_duplicates(subset='date', keep='first')

# %%
RDD
# Out:
#         date  value
# 0 2024-01-01      1
# 1 2024-01-02      2
# 3 2024-01-03      4

# %% [markdown]
# Menambahkan nilai kosong

# %%
import pandas as pd
import numpy as np

# %%
data_NAN = {'date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05'], 'value': [1, np.nan, 3, np.nan, 5]}

# %%
df_NAN = pd.DataFrame(data_NAN)
df_NAN
# Out:
#          date  value
# 0  2022-01-01    1.0
# 1  2022-01-02    NaN
# 2  2022-01-03    3.0
# 3  2022-01-04    NaN
# 4  2022-01-05    5.0

# %%
df_NAN['date'] = pd.to_datetime(df_NAN['date'])

# %%
df_NAN['value'] = df_NAN['value'].fillna(method='ffill')

df_NAN
# Out:
#         date  value
# 0 2022-01-01    1.0
# 1 2022-01-02    1.0
# 2 2022-01-03    3.0
# 3 2022-01-04    3.0
# 4 2022-01-05    5.0
